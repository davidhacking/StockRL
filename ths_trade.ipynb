# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import datetime
import time
import os

from utils import run_exp_strategy
from utils import config

# %%
def ths_trade():
    r = run_exp_strategy.RunExpStrategy()
    r.total_timesteps = 200000
    r.exp_id = 8
    r.start_date = "20090101"
    r.split_date = datetime.datetime.now().strftime("%Y%m%d")
    r.end_date = datetime.datetime.now().strftime("%Y%m%d")
    r.a_stock_list = "SSE_50_EXT"
    r.stocks = config.__dict__[r.a_stock_list]
    r.h_stock_list = ""
    r.usa_stock_list = ""
    r.baseline_stocks = "SSE_50_INDEX"
    r.no_tushare = True
    r.rerun_test = True
    r.redownload_data = True
    r.need_pe = True
    r.state_init_func = "AllCashStateIntiator"
    r.user_stock_account = "ThsUserStockAccount"
    r.initial_amount = 150000
    r.hmax = 5000
    r.env_params["hmax"] = r.hmax
    r.trade_env_params["initial_amount"] = r.initial_amount
    r.trade_env_params["initial_amount"] = r.initial_amount
    r.test_model_names = ["ddpg"]
    r.create_exp_dir()
    r.download_stock_data()
    r.download_baseline_stocks()
    r.split_train_and_test_data()
    r.train_model()
    r.test_model()

# %%
ths_trade()
# Out:
# 2025-01-10 13:43:46,157 | 3284375 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1, host=127.0.0.1, port=11111, user_id=12316428
# 2025-01-10 13:45:20,719 | 3284375 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=1
# 成功添加技术指标
# 对当前时间段未上市的公司的所有行置零
# 2025-01-10 13:45:27,371 | 3284375 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=2, host=127.0.0.1, port=11111, user_id=12316428
# 2025-01-10 13:45:27,399 | 3284375 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=2
# 2025-01-10 13:45:29,031 | 3284375 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=3, host=127.0.0.1, port=11111, user_id=12316428
# 加载数据缓存
# 数据缓存成功!
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# 2025-01-10 13:45:29,075 | 3284375 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=3
# /home/david/miniconda3/envs/stock_rl/lib/python3.10/site-packages/stable_baselines3/common/save_util.py:418: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   th_object = th.load(file_content, map_location=device)
# ThsUserStockAccount cash=86498.43 qty_info={'600000.SH': 1100, '600009.SH': 100, '600028.SH': 600, '600030.SH': 100, '600031.SH': 100, '600048.SH': 500, '600196.SH': 300, '600547.SH': 800, '600570.SH': 100, '600690.SH': 100, '600703.SH': 400, '600837.SH': 400, '600918.SH': 700, '601288.SH': 900, '601688.SH': 300, '601933.SH': 1300, '000100.SZ': 5120} h=[5120. 1100.  100.    0.  600.  100.  100.    0.  500.    0.    0.  300.
#     0.    0.    0.  800.  100.    0.    0.  100.  400.    0.  400.    0.
#   700.    0.    0.    0.    0.    0.    0.    0.    0.  900.    0.    0.
#     0.    0.    0.    0.    0.  300.    0.    0.    0.    0. 1300.    0.
#     0.    0.    0.    0.]
# after obs=[ 8.64984297e+04  5.12000000e+03  1.10000000e+03  1.00000000e+02
#   0.00000000e+00  6.00000000e+02  1.00000000e+02  1.00000000e+02
#   0.00000000e+00  5.00000000e+02  0.00000000e+00  0.00000000e+00
#   3.00000000e+02  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   8.00000000e+02  1.00000000e+02  0.00000000e+00  0.00000000e+00
#   1.00000000e+02  4.00000000e+02  0.00000000e+00  4.00000000e+02
#   0.00000000e+00  7.00000000e+02  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  9.00000000e+02  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  3.00000000e+02  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  1.30000000e+03
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  5
| 3284375 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=4, host=127.0.0.1, port=11111, user_id=12316428
# sell_stock= sell?code=600009&qty=100&price=32.62
# sell_stock return= {"message": "success"}
# cur_price SH.600028
# 2025-01-10 13:45:45,417 | 3284375 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=5, host=127.0.0.1, port=11111, user_id=12316428
# sell_stock= sell?code=600028&qty=600&price=6.35
# sell_stock return= {"entrust_no": "33261"}
# cur_price SH.600031
# 2025-01-10 13:45:53,368 | 3284375 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=6, host=127.0.0.1, port=11111, user_id=12316428
# sell_stock= sell?code=600031&qty=100&price=15.52
# sell_stock return= {"entrust_no": "33287"}
# cur_price SH.600196
# 2025-01-10 13:46:01,381 | 3284375 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=7, host=127.0.0.1, port=11111, user_id=12316428
# sell_stock= sell?code=600196&qty=200&price=23.78
# sell_stock return= {"entrust_no": "33303"}
# cur_price SH.600703
# 2025-01-10 13:46:09,586 | 3284375 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=8, host=127.0.0.1, port=11111, user_id=12316428
# sell_stock= sell?code=600703&qty=400&price=11.24
# sell_stock return= {"entrust_no": "33315"}
# cur_price SH.600837
# 2025-01-10 13:46:17,664 | 3284375 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=9, host=127.0.0.1, port=11111, user_id=12316428
# sell_stock= sell?code=600837&qty=400&price=10.51
# sell_stock failed: 500 Server Error: INTERNAL SERVER ERROR for url: http://127.0.0.1:5555/sell?code=600837&qty=400&price=10.51
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ths_trade()
#
# Cell In[2], line 30, in ths_trade()
#      28 r.split_train_and_test_data()
#      29 r.train_model()
# ---> 30 r.test_model()
#
# File ~/MF/github/StockRL/utils/run_exp_strategy.py:550, in RunExpStrategy.test_model(self)
#     546     self.user_stock_account_ins_dict[model_name] = UserStockAccountFactory[self.user_stock_account](
#     547         self.test_code2index
#     548     )
#     549     self.user_stock_account_ins_dict[model_name].close_dict = self.last_close_dict
# --> 550 self.test_model_by_model_name(model_name)
#
# File ~/MF/github/StockRL/utils/run_exp_strategy.py:534, in RunExpStrategy.test_model_by_model_name(self, model_name)
#     532 model.load(model_path)
#     533 if model is not None:
# --> 534     df_account_value, df_actions = DRL_Agent.DRL_prediction(model=model,
#     535                                                             environment=e_trade_gym,
#     536                                                             user_stock_account=self.user_stock_account_ins_dict[model_name])
#     537     df_account_value.to_csv(account_value_path, index=False)
#     539     actions_path = os.path.join(self.exp_dir, "actions_{}.csv".format(model_name))
#
# File ~/MF/github/StockRL/utils/models.py:322, in DRL_Agent.DRL_prediction(model, environment, user_stock_account)
#     320         import sys
#     321         sys.exit(0)
# --> 322     user_stock_account.take_action(
#     323         date=test_env.env_method(method_name="get_dates")[0],
#     324         action=action[0],
#     325         spend=spend[0],
#     326         costs=costs[0],
#     327         cash_and_sell_stock_money=coh[0],
#     328         closings=closings
#     329     )
#     330 test_obs, _, dones, _ = test_env.step(predict_action)
#     331 if i == (len_environment - 2):
#
# File ~/MF/github/StockRL/utils/models.py:238, in ThsUserStockAccount.take_action(self, date, action, **kwargs)
#     236     price = cur_price(code)
#     237     ths_trader.sell_stock(remove_market(code), price, int(qty))
# --> 238 time.sleep(60)
#     239 for code, qty in buys.items():
#     240     price = self.close_dict.get(revert_code(code), 0)
#
# KeyboardInterrupt:
