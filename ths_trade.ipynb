# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import datetime
import time
import os

from utils import run_exp_strategy
from utils import config

# %%
def ths_trade():
    r = run_exp_strategy.RunExpStrategy()
    r.total_timesteps = 200000
    r.exp_id = 8
    r.start_date = "20090101"
    r.split_date = datetime.datetime.now().strftime("%Y%m%d")
    r.end_date = datetime.datetime.now().strftime("%Y%m%d")
    r.a_stock_list = "SSE_50_EXT"
    r.stocks = config.__dict__[r.a_stock_list]
    r.h_stock_list = ""
    r.usa_stock_list = ""
    r.baseline_stocks = "SSE_50_INDEX"
    r.no_tushare = True
    r.rerun_test = True
    r.redownload_data = True
    r.need_pe = True
    r.state_init_func = "AllCashStateIntiator"
    r.user_stock_account = "ThsUserStockAccount"
    r.initial_amount = 150000
    r.hmax = 5000
    r.env_params["hmax"] = r.hmax
    r.trade_env_params["initial_amount"] = r.initial_amount
    r.trade_env_params["initial_amount"] = r.initial_amount
    r.test_model_names = ["td3"]
    r.create_exp_dir()
    r.download_stock_data()
    r.download_baseline_stocks()
    r.split_train_and_test_data()
    r.train_model()
    r.test_model()

# %%
ths_trade()
# Out:
# 2024-12-19 14:03:08,209 | 827786 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1, host=127.0.0.1, port=11111, user_id=12316428
# 2024-12-19 14:04:37,438 | 827786 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=1
# 成功添加技术指标
# 对当前时间段未上市的公司的所有行置零
# 2024-12-19 14:04:44,096 | 827786 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=2, host=127.0.0.1, port=11111, user_id=12316428
# 2024-12-19 14:04:44,120 | 827786 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=2
# 2024-12-19 14:04:45,802 | 827786 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=3, host=127.0.0.1, port=11111, user_id=12316428
# 加载数据缓存
# 2024-12-19 14:04:45,826 | 827786 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=3
# 数据缓存成功!
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# /home/david/miniconda3/envs/stock_rl/lib/python3.10/site-packages/stable_baselines3/common/save_util.py:418: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   th_object = th.load(file_content, map_location=device)
# ThsUserStockAccount cash=45578.43 qty_info={'600000.SH': 1500, '600028.SH': 1400, '600031.SH': 300, '600036.SH': 100, '600547.SH': 200, '600703.SH': 300, '600837.SH': 400, '600887.SH': 100, '601211.SH': 200, '601398.SH': 700, '601628.SH': 200, '601816.SH': 800, '601818.SH': 1300, '601933.SH': 2900, '000100.SZ': 2420} h=[2420. 1500.    0.    0. 1400.    0.  300.  100.    0.    0.    0.    0.
#     0.    0.    0.  200.    0.    0.    0.    0.  300.    0.  400.  100.
#     0.    0.    0.    0.    0.    0.    0.  200.    0.    0.    0.    0.
#     0.  700.    0.  200.    0.    0.  800. 1300.    0.    0. 2900.    0.
#     0.    0.    0.    0.]
# after obs=[ 4.55784297e+04  2.42000000e+03  1.50000000e+03  0.00000000e+00
#   0.00000000e+00  1.40000000e+03  0.00000000e+00  3.00000000e+02
#   1.00000000e+02  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   2.00000000e+02  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  3.00000000e+02  0.00000000e+00  4.00000000e+02
#   1.00000000e+02  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   2.00000000e+02  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  7.00000000e+02  0.00000000e+00
#   2.00000000e+02  0.00000000e+00  0.00000000e+00  8.00000000e+02
#   1.30000000e+03  0.00000000e+00  0.00000000e+00  2.90000000e+03
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  5
# close_dict= {'000100.SZ': 5.15, '600000.SH': 9.49, '600009.SH': 34.26, '600016.SH': 4.02, '600028.SH': 6.45, '600030.SH': 30.31, '600031.SH': 16.46, '600036.SH': 38.01, '600048.SH': 9.32, '600050.SH': 5.35, '600104.SH': 18.15, '600196.SH': 25.96, '600276.SH': 46.38, '600309.SH': 74.31, '600519.SH': 1556.6, '600547.SH': 23.49, '600570.SH': 29.8, '600585.SH': 24.47, '600588.SH': 12.42, '600690.SH': 28.53, '600703.SH': 12.61, '600745.SH': 35.89, '600837.SH': 11.38, '600887.SH': 29.45, '600918.SH': 6.79, '601012.SH': 16.62, '601066.SH': 26.68, '601088.SH': 42.65, '601138.SH': 22.17, '601166.SH': 18.52, '601186.SH': 9.29, '601211.SH': 18.74, '601236.SH': 8.4, '601288.SH': 5.04, '601318.SH': 52.73, '601319.SH': 7.36, '601336.SH': 49.4, '601398.SH': 6.5, '601601.SH': 33.68, '601628.SH': 41.68, '601668.SH': 5.97, '601688.SH': 17.92, '601816.SH': 6.14, '601818.SH': 3.71, '601857.SH': 8.42, '601888.SH': 69.86, '601933.SH': 6.32, '603160.SH': 84.45, '603259.SH': 56.05, '603288.SH': 46.87, '603501.SH': 103.4, '603986.SH': 111.81}
# take_action= [ -900.  -500.     0.     0.   700.     0.   300.   100.   500.   900.
#    200.     0.     0.     0.     0.   200.   100.   200.   400.     0.
#   -300.   100.   400.  -100.     0.   300.     0.   100.   200.   200.
#      0.  -200.   500.     0.     0.     0.     0.  -700.     0.   100.
#    800.     0.  -800. -1300.   500.     0.  -700.     0.     0.   100.
#      0.     0.]
# selllist= {'SZ.000100': 900.0, 'SH.600000': 500.0, 'SH.600703': 300.0, 'SH.600887': 100.0, 'SH.601211': 200.0, 'SH.601398': 700.0, 'SH.601816': 800.0, 'SH.601818': 1300.0, 'SH.601933': 700.0}
# buylist= {'SH.600028': 700.0, 'SH.600031': 300.0, 'SH.600036': 100.0, 'SH.600048': 500.0, 'SH.600050': 900.0, 'SH.600104': 200.0, 'SH.600547': 200.0, 'SH.600570': 100.0, 'SH.600585': 200.0, 'SH.600588': 400.0, 'SH.600745': 100.0, 'SH.600837': 400.0, 'SH.601012': 300.0, 'SH.601088': 100.0, 'SH.601138': 200.0, 'SH.601166': 200.0, 'SH.601236': 500.0, 'SH.601628': 100.0, 'SH.601668': 800.0, 'SH.601857': 500.0, 'SH.603288': 100.0}
# sell_stock= sell?code=000100&qty=900&price=5.15
# sell_stock return= {"message": "success"}
# sell_stock= sell?code=600000&qty=500&price=9.49
# sell_stock return= {"entrust_no": "42675"}
# sell_stock= sell?code=600703&qty=300&price=12.61
# sell_stock failed: 500 Server Error: INTERNAL SERVER ERROR for url: http://127.0.0.1:5555/sell?code=600703&qty=300&price=12.61
# sell_stock= sell?code=600887&qty=100&price=29.45
# sell_stock return= {"entrust_no": "42709"}
# sell_stock= sell?code=601211&qty=200&price=18.74
# sell_stock failed: 500 Server Error: INTERNAL SERVER ERROR for url: http://127.0.0.1:5555/sell?code=601211&qty=200&price=18.74
# sell_stock= sell?code=601398&qty=700&price=6.5
# sell_stock return= {"entrust_no": "42753"}
# sell_stock= sell?code=601816&qty=800&price=6.14
# sell_stock return= {"entrust_no": "42771"}
# sell_stock= sell?code=601818&qty=1300&price=3.71
# sell_stock return= {"entrust_no": "42783"}
# sell_stock= sell?code=601933&qty=700&price=6.32
# sell_stock failed: 500 Server Error: INTERNAL SERVER ERROR for url: http://127.0.0.1:5555/sell?code=601933&qty=700&price=6.32
# buy_stock= buy?code=600028&qty=700&price=6.45
# buy_stock return= {"message": "success"}
# buy_stock= buy?code=600031&qty=300&price=16.46
# buy_stock return= {"entrust_no": "42870"}
# buy_stock= buy?code=600036&qty=100&price=38.01
# buy_stock failed: 500 Server Error: INTERNAL SERVER ERROR for url: http://127.0.0.1:5555/buy?code=600036&qty=100&price=38.01
# buy_stock= buy?code=600048&qty=500&price=9.32
# buy_stock return= {"message": "success"}
# buy_stock= buy?code=600050&qty=900&price=5.35
# buy_stock return= {"message": "success"}
# buy_stock= buy?code=600104&qty=200&price=18.15
# buy_stock return= {"message": "success"}
# buy_stock= buy?code=600547&qty=200&price=23.49
# buy_stock return= {"message": "success"}
# buy_stock= buy?code=600570&qty=100&price=29.8
# buy_stock return= {"message": "success"}
# buy_stock= buy?code=600585&qty=200&price=24.47
# buy_stock return= {"message": "success"}
# buy_stock= buy?code=600588&qty=400&price=12.42
# buy_stock return= {"message": "success"}
# buy_stock= buy?code=600745&qty=100&price=35.89
# buy_stock return= {"message": "success"}
# buy_stock= buy?code=600837&qty=400&price=11.38
# buy_stock return= {"message": "success"}
# buy_stock= buy?code=601012&qty=300&price=16.62
# buy_stock failed: 500 Server Error: INTERNAL SERVER ERROR for url: http://127.0.0.1:5555/buy?code=601012&qty=300&price=16.62
# buy_stock= buy?code=601088&qty=100&price=42.65
# buy_stock return= {"message": "success"}
# buy_stock= buy?code=601138&qty=200&price=22.17
# buy_stock return= {"message": "success"}
# buy_stock= buy?code=601166&qty=200&price=18.52
# buy_stock return= {"message": "success"}
# buy_stock= buy?code=601236&qty=500&price=8.4
# buy_stock return= {"message": "success"}
# buy_stock= buy?code=601628&qty=100&price=41.68
# buy_stock failed: 500 Server Error: INTERNAL SERVER ERROR for url: http://127.0.0.1:5555/buy?code=601628&qty=100&price=41.68
# buy_stock= buy?code=601668&qty=800&price=5.97
# buy_stock failed: 500 Server Error: INTERNAL SERVER ERROR for url: http://127.0.0.1:5555/buy?code=601668&qty=800&price=5.97
# buy_stock= buy?code=601857&qty=500&price=8.42
# buy_stock failed: 500 Server Error: INTERNAL SERVER ERROR for url: http://127.0.0.1:5555/buy?code=601857&qty=500&price=8.42
# buy_stock= buy?code=603288&qty=100&price=46.87
# buy_stock failed: 500 Server Error: INTERNAL SERVER ERROR for url: http://127.0.0.1:5555/buy?code=603288&qty=100&price=46.87
# EPISODE|STEPS|TERMINAL_REASON|CASH           |TOT_ASSETS     |TERMINAL_REWARD|GAINLOSS_PCT|RETREAT_PROPORTION
#    1|   0|Last Date      |￥150,000       |￥150,000       |0.00000%  |0.00000%  |0.00%
# 回测完成!
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ths_trade()
#
# Cell In[2], line 30, in ths_trade()
#      28 r.split_train_and_test_data()
#      29 r.train_model()
# ---> 30 r.test_model()
#
# File ~/MF/github/StockRL/utils/run_exp_strategy.py:549, in RunExpStrategy.test_model(self)
#     545     self.user_stock_account_ins_dict[model_name] = UserStockAccountFactory[self.user_stock_account](
#     546         self.test_code2index
#     547     )
#     548     self.user_stock_account_ins_dict[model_name].close_dict = self.last_close_dict
# --> 549 self.test_model_by_model_name(model_name)
#
# File ~/MF/github/StockRL/utils/run_exp_strategy.py:533, in RunExpStrategy.test_model_by_model_name(self, model_name)
#     531 model.load(model_path)
#     532 if model is not None:
# --> 533     df_account_value, df_actions = DRL_Agent.DRL_prediction(model=model,
#     534                                                             environment=e_trade_gym,
#     535                                                             user_stock_account=self.user_stock_account_ins_dict[model_name])
#     536     df_account_value.to_csv(account_value_path, index=False)
#     538     actions_path = os.path.join(self.exp_dir, "actions_{}.csv".format(model_name))
#
# File ~/MF/github/StockRL/utils/models.py:314, in DRL_Agent.DRL_prediction(model, environment, user_stock_account)
#     312         print("回测完成!")
#     313         break
# --> 314 return account_memory[0], actions_memory[0]
#
# IndexError: list index out of range
